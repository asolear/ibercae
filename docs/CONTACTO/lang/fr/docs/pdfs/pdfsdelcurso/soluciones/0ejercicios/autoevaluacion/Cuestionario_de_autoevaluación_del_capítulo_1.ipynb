# %% [markdown]
# # Pregunta 1
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Tenemos un edificio con una caldera de gasóleo que consume 100.000kWh/año en calefacción. Se ha realizado una propuesta por cambiar la caldera por una bomba de calor que pasaría a consumir 36.000kWh/año de electricidad en calefacción.
#
# ¿Cuál ha sido el ahorro de emisiones en kg de CO2 según los datos de 2005?
#
# Nota: usar los ratios usados  por el CALENER.
# Respuesta:

# %%
go=100000 #kWh/año
ego=1.081
egot=go*ego
egot
# 
e=36000#kWh/año
ee=2.903
eet=e*ee

# %%
# 
egot-eet
# Out:
# 3592.0

# %% [markdown]
# # Pregunta 2
# Respuesta guardada
# Puntúa como 0,50
# Marcar pregunta
# Enunciado de la pregunta
#
# ¿Y que ahorro tendríamos según los nuevos datos del IDAE?
#
#
# Respuesta:

# %%
go=100000 #kWh/año
ego=1.179
egot=go*ego
egot
# 
e=36000#kWh/año
ee=1.954
eet=e*ee
egot-eet
# Out:
# 47556.0

# %% [markdown]
# # Pregunta 3
# Respuesta guardada
# Puntúa como 0,50
# Marcar pregunta
# Enunciado de la pregunta
#
# ¿Qué gobierno del bloque BRICS sostiene que  su país emite el 4,7% de las emisiones mundiales?
# Seleccione una:
# a. Rusia
# b. China
# c. India
# d. Brasil
# # Pregunta 4
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# A partir de qué fecha los edificios públicos tiene que ser edificios de consumo de energías casi nula.
# Seleccione una:
# a. 31 Diciembre de 2020
# b. 15 Agosto de de 2019
# c. 31 Diciembre de 2018
# d. Nunca
# # Pregunta 5
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# ¿Puede usar una empresa su certificado de eficiencia energética de los edificios para quedar exenta de la auditoria que obliga la propuesta de real decreto para la transposición de la Directiva Europea 2012/27/UE?
# Seleccione una:
# a. No porque son de normativas diferentes.
# b. Sí pero solo en las partes de la empresa cubiertas por el certificado teniendo que hacer la auditoria del resto de la empresa.
# c. Sí, son documentos equivalentes.
# d. Es al revés, la auditoria energética sustituye el certificado de eficiencia energética de los edificios.
# # Pregunta 6
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# ¿Cuáles de los siguientes datos pediremos de inicio a la empresa auditada?
# Seleccione una o más de una:
# a. Período de vacaciones.
# b. Fichas técnicas de los equipos consumidores de energía
# c. Datos personales de todos los trabajadores de la empresa.
# d. Facturas energéticas.
# e. Balance económico de la empresa.
# f. Producción anual.
# # Pregunta 7
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# La visita in situ sirve para:
# Seleccione una:
# a. Realizar la reuniones necesarias con los usuarios del edificio.
# b. Realizar las mediciones planeadas anteriormente.
# c. Recoger información para el inventario energético
# d. Todas las anteriores
# # Pregunta 8
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# La contabilidad energética consiste en
# Seleccione una:
# a. Conocer el estado energético actual así como los índices energéticos.
# b. Recoger la información técnica de los equipos más consumidores de energía.
# c. Realizar las mediciones necesarias.
# d. Conocer el beneficio económico de la empresa.
# # Pregunta 9
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Una propuesta de mejora tiene que contener:
# Seleccione una:
# a. La inversión necesaria.
# b. Comparativa consumo energético entre situación futura y actual.
# c. El cálculo de la viabilidad económica de la propuesta.
# d. Todas la anteriores.
# # Pregunta 10
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Relaciona las tareas con la fase coSrrespondiente
#
# Solicitud Datos de partida
#
# Respuesta 1
#
# Revisión Documentación técnica
#
# Respuesta 2
#
# Visita in situ
#
# Respuesta 3
#
# Inventario energético
#
# Respuesta 4
#
# Contabilidad energética
#
# Respuesta 5
#
# Propuesta de mejora
#
# Respuesta 6
#
# Informe Final
#
# Respuesta 7
# Pregunta 11
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# El informe final tiene que contener:
# Seleccione una:
# a. Estudio de seguridad y salud
# b. Distribución de la  energía por usos
# c. Ficha del catastro del edificio
# d. Ninguna de las anteriores
