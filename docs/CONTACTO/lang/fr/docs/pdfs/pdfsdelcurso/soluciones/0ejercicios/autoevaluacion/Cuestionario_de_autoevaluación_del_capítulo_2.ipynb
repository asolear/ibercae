# %% [markdown]
# hola caracola

# %% [markdown]
# # Cuestionario de autoevaluación del capítulo 2
#
# Saltar a contenido principal
# cogitiformacion
#
#     Francisco Manuel RomanImagen de Francisco Manuel Roman
#
# Ayuda
# Mostrar/ocultar menú de mensajes
# 1
# Marcar como leído Preferencias de mensajes
# Mostrar/ocultar menú de notificaciones
# Marcar como leído Preferencias de notificación
#
# Auditorías energéticas
# Ruta a la página
#
#     Área personal / ► Mis cursos / ► Auditorías energéticas / ► Capítulo 2 - Contabilidad energética / ► Cuestionario de autoevaluación del capítulo 2
#
# ## Pregunta 1
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Si una sucursal de una empresa situada en A tiene 1231 Grados día de calefacción y otra sucursal  situada en B tiene 843 Grados día de calefacción sabremos qué:
# Seleccione una:
# a. La demanda de refrigeración será mayor en la sucursal situada en B.
# b. La demanda de climatización será mayor en la sucursal situada en A.
# c. La demanda de calefacción será mayor en la sucursal situada en A.
# d. Todas la anteriores.
# ## Pregunta 2
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Las variaciones de consumo en un cuadro eléctrico secundario las detectaremos en el análisis de:
# Seleccione una:
# a. Del consumo mensual de las facturas de compañía
# b. Del consumo de los contadores internos de la misma zona
# c. De las mediciones del cuadro principal
# d. Ninguna de las anteriores
# ## Pregunta 3
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# En el análisis de la facturación de una tarifa 3.0 podremos detectar:
# Seleccione una:
# a. Consumos durante el período nocturn (de 0h a 8h)
# b. Consumos durante el fin de semana.
# c. La punta máxima de demanda eléctrica.
# d. Todas la anteriores.
# ## Pregunta 4
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# En el análisi del consumo energético de combustible...
# Seleccione una:
# a. …compararemos el horario laboral con los consumos en los períodos valle,  punta y llano.
# b. …trasladaremos todos el consumo al período llano ya que es el mas económico.
# c. …detectaremos los períodos del año dónde tenemos mas consumo de combustible.
# d. Todas la anteriores.
# ## Pregunta 5
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# ¿Qué consumo energético tuvo de 10h a 11h del día 1/07/2011 el SB0 de la industria que hemos utilizado como ejemplo en el capítulo?
#
# Nota: tenéis de que obtener el dato del powervision.
# Seleccione una:
# a. 70,01 kWh
# b. 76,19 kWh
# c. 128 kW
# d. 1544,91 kWh
# ## Pregunta 6
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Los grados día de refrigeración del verano de 2018 (junio-octubre) para una temperatura base de 20ºC, un edificio situado en Santa Cruz de Tenerife son de:
#
# Nota: utilizar el dregreedays.net y los datos de una estación meteorológica situada en un aeropuerto cerca de la ciudad.
# Seleccione una:
# a. 184
# b. 129
# c. 1417
# d. 240
# ## Pregunta 7
# Respuesta guardada
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# ¿A qué hora habrías puesto la lavadora el día 20 de Enero de 2015 si tuvieras una tarifa 2.0?
#
# Nota: podéis usar la web tarifaluzhora.es
# Seleccione una:
# a. Entre las 21-22h
# b. Entre las 00 y las 01h
# c. Entre las 01 y las 02h
# d. Entre las 10h y las 11h
# ## Pregunta 8
# Sin responder aún
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Tenemos una empresa con los siguientes consumos energéticos.
#
# ex
#
# a) Halla el ratio energético de kWh/hora trabajada para electricidad:
# Respuesta
#
# b) Halla el ratio energético de kWh/grados día calefacción para combustible:
# Respuesta
#
#
#
# Nota: entrad el valor con 2 decimales.

# %%
# ///////////////////////////////////////////////
#  definir en las tablas las variables
import numpy as np
import pandas as pd
import datetime

pd.options.mode.chained_assignment = None  # default='warn'
import matplotlib.pyplot as plt
import base64
from io import BytesIO



# ls datos/efe*.*
df=pd.DataFrame()

df=pd.read_csv("datos/autoevaluacion2.csv", index_col=0, header=0)
df
# df.columns =['p1','p2','p3','p4','p5','p6']
# Out:
#      Electricidad  Combustible  Horas_trabajadas  Grado_dia_calefaccion
# mes
# 1           31467         3133              6427                    407
# 2           26864         2553              7561                    408
# 3           35858         2091              8695                    242
# 4           30416         1925              7183                    167
# 5           42341         1404              8695                     75
# 6           45533         1130              7939                     19
# 7           50148          903              8695                     12
# 8           47956          817              4915                      5
# 9           36467         1151              7561                     35
# 10          35424         1643              8695                     92
# 11          30048         2152              8317                    205
# 12          31629         2953              6427                    368

# %%
ratio_electrico=round(df.Electricidad.sum()/df.Horas_trabajadas.sum(),2)
ratio_combustible=round(df.Combustible.sum()/df.Grado_dia_calefaccion.sum(),2)
ratio_electrico,ratio_combustible
# Out:
# (4.87, 10.74)

# %%
# df.Electricidad

# %% [markdown]
#
# ## Pregunta 9
# Sin responder aún
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# Con los datos del ejemplo anterior calcular las lineas bases energéticas (lineales) y el coeficiente de regresión r2.
#
#  a) El coeficiente r2 para electricidad – hora trabajada es de :
# Respuesta
#
#  b) El coeficiente r2 para combustible – grado día es de :
# Respuesta
#
#  Nota: entrad el valor con 4 decimales.

# %%
y=df.Electricidad
x=df.Horas_trabajadas
# Polynomial Regression
def polyfit(x, y, degree):
    results = {}

    coeffs = np.polyfit(x, y, degree)

     # Polynomial Coefficients
    results['polynomial'] = coeffs.tolist()

    # r-squared
    p = np.poly1d(coeffs)
    # fit values, and mean
    yhat = p(x)                         # or [p(z) for z in x]
    ybar = np.sum(y)/len(y)          # or sum(y)/len(y)
    ssreg = np.sum((yhat-ybar)**2)   # or sum([ (yihat - ybar)**2 for yihat in yhat])
    sstot = np.sum((y - ybar)**2)    # or sum([ (yi - ybar)**2 for yi in y])
    results['determination'] = ssreg / sstot

    return results
degree=1
model=np.polyfit(x, y, degree)
predict = np.poly1d(model)
model1= polyfit(x, y, degree)
m=round(model1['polynomial'][0],1)
b=round(model1['polynomial'][1],1)
R2=round(model1['determination'],3)


tt='Regresion lineal   y = '+str(m)+' x + '+str(b)+';  $R^2=$'+str(R2)
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax = plt.scatter(x,y)
ax = plt.suptitle(tt)
# ax = plt.ylabel("kwh")
x_lin_reg = range(0, x.max())
y_lin_reg = predict(x_lin_reg)
ax = plt.scatter(x, y)
ax = plt.plot(x_lin_reg, y_lin_reg, c = 'b')

img = BytesIO()
plt.savefig(img, format='png')
img.seek(0)
plot_url = base64.b64encode(img.getvalue()).decode()
dfa_g = ('<img src="data:image/png;base64,{}">'.format(plot_url))
# plt.close()

# %%
y=df.Combustible
x=df.Grado_dia_calefaccion
# Polynomial Regression
def polyfit(x, y, degree):
    results = {}

    coeffs = np.polyfit(x, y, degree)

     # Polynomial Coefficients
    results['polynomial'] = coeffs.tolist()

    # r-squared
    p = np.poly1d(coeffs)
    # fit values, and mean
    yhat = p(x)                         # or [p(z) for z in x]
    ybar = np.sum(y)/len(y)          # or sum(y)/len(y)
    ssreg = np.sum((yhat-ybar)**2)   # or sum([ (yihat - ybar)**2 for yihat in yhat])
    sstot = np.sum((y - ybar)**2)    # or sum([ (yi - ybar)**2 for yi in y])
    results['determination'] = ssreg / sstot

    return results
degree=1
model=np.polyfit(x, y, degree)
predict = np.poly1d(model)
model1= polyfit(x, y, degree)
m=round(model1['polynomial'][0],1)
b=round(model1['polynomial'][1],1)
R2=round(model1['determination'],3)


tt='Regresion lineal   y = '+str(m)+' x + '+str(b)+';  $R^2=$'+str(R2)
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax = plt.scatter(x,y)
ax = plt.suptitle(tt)
# ax = plt.ylabel("kwh")
x_lin_reg = range(0, x.max())
y_lin_reg = predict(x_lin_reg)
ax = plt.scatter(x, y)
ax = plt.plot(x_lin_reg, y_lin_reg, c = 'b')

img = BytesIO()
plt.savefig(img, format='png')
img.seek(0)
plot_url = base64.b64encode(img.getvalue()).decode()
dfa_g = ('<img src="data:image/png;base64,{}">'.format(plot_url))
# plt.close()

# %% [markdown]
# ## Pregunta 10
# Sin responder aún
# Puntúa como 1,00
# Marcar pregunta
# Enunciado de la pregunta
#
# ¿Se puede usar las dos líneas base calculadas en el ejercicio anterior  para la predicción del consumo futuro de esta indústria?
# Seleccione una:
# a. Si, son correctas.
# b. No, ninguna de las dos es útil.
# c. Solo la de combustible.
# d. Solo la de electricidad.
# Saltar Navegación por el cuestionario
# Navegación por el cuestionario
# Pregunta 1 Esta página
# Pregunta 2 Esta página
# Pregunta 3 Esta página
# Pregunta 4 Esta página
# Pregunta 5 Esta página
# Pregunta 6 Esta página
# Pregunta 7 Esta página
# Pregunta 8 Esta página
# Pregunta 9 Esta página
# Pregunta 10 Esta página
# Terminar intento...
#
# Usted se ha identificado como Francisco Manuel Roman (Salir)
# 0107-auditorias-energeticas

# %%
# %%html
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="
# Curso:  Auditorías energéticas
# Alumno: Francisco Manuel Roman Gamez
#
# "></form>
